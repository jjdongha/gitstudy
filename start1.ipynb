# %% [markdown]
# <a href="https://colab.research.google.com/github/jjdongha/gitstudy/blob/master/start1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x<-c(1,2,3,4)
y<-c(3,4,4,5)
x
y
plot(x,y)
fit <- lm(y~x)
abline(fit)
# Out:
# [1] 1 2 3 4
# [1] 3 4 4 5
# plot without title

# %%
names(cars)
dim(cars)
plot(cars$speed,cars$dist)
fit <- lm(dist~speed, data=cars)
abline(fit)
fit
# Out:
# [1] "speed" "dist"
# [1] 50  2
# Call:
# lm(formula = dist ~ speed, data = cars)
#
# Coefficients:
# (Intercept)        speed
#     -17.579        3.932
# plot without title
